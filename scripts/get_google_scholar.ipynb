# %%
from scholarly import scholarly

# %%
author = scholarly.search_author_id('CnTTa3EAAAAJ')

# %%
scholarly.pprint(author)
# Out:
# b"{'affiliation': 'University of Tokyo',\n 'citedby': 313,\n 'email_domain': '@g.ecc.u-tokyo.ac.jp',\n 'filled': False,\n 'homepage': 'http://haozhou.wang/',\n 'interests': ['Forest Inventory', 'Computer vision', 'UAV'],\n 'name': 'Haozhou WANG',\n 'organization': 8929680262811525562,\n 'scholar_id': 'CnTTa3EAAAAJ',\n 'source': 'AUTHOR_PROFILE_PAGE',\n 'url_picture': 'https://scholar.googleusercontent.com/citations?view_op=view_photo&user=CnTTa3EAAAAJ&citpid=9'}"

# %%
author
# Out:
# {'container_type': 'Author',
#  'filled': ['basics'],
#  'scholar_id': 'CnTTa3EAAAAJ',
#  'source': <AuthorSource.AUTHOR_PROFILE_PAGE: 'AUTHOR_PROFILE_PAGE'>,
#  'name': 'Haozhou WANG',
#  'url_picture': 'https://scholar.googleusercontent.com/citations?view_op=view_photo&user=CnTTa3EAAAAJ&citpid=9',
#  'affiliation': 'University of Tokyo',
#  'organization': 8929680262811525562,
#  'interests': ['Forest Inventory', 'Computer vision', 'UAV'],
#  'email_domain': '@g.ecc.u-tokyo.ac.jp',
#  'homepage': 'http://haozhou.wang/',
#  'citedby': 313}

# %%
sout = scholarly.fill(author, sections=['indices', 'counts'])

sout.keys()
# Out:
# dict_keys(['container_type', 'filled', 'scholar_id', 'source', 'name', 'url_picture', 'affiliation', 'organization', 'interests', 'email_domain', 'homepage', 'citedby', 'citedby5y', 'hindex', 'hindex5y', 'i10index', 'i10index5y', 'coauthors', 'cites_per_year'])

# %%
sout['hindex']
# Out:
# 8

# %%
sout['cites_per_year']
# Out:
# {2019: 1, 2020: 9, 2021: 33, 2022: 51, 2023: 67, 2024: 99, 2025: 51}
