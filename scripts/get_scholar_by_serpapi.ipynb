# %%
from serpapi import GoogleSearch

# %%
params = {
  "engine": "google_scholar_author",
  "author_id": "CnTTa3EAAAAJ",
  "api_key": "569a91d904f3b632e404192f808954add02040eb27f1241d2e887073894b0f64"
}

# %%
search = GoogleSearch(params)
results = search.get_dict()

# %%
results
# Out:
# {'search_metadata': {'id': '68348b7f6c4c0c0f9e544c47',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/d9987d9766ea50ca/68348b7f6c4c0c0f9e544c47.json',
#   'created_at': '2025-05-26 15:40:47 UTC',
#   'processed_at': '2025-05-26 15:40:47 UTC',
#   'google_scholar_author_url': 'https://scholar.google.com/citations?user=CnTTa3EAAAAJ&hl=en',
#   'raw_html_file': 'https://serpapi.com/searches/d9987d9766ea50ca/68348b7f6c4c0c0f9e544c47.html',
#   'total_time_taken': 1.14},
#  'search_parameters': {'engine': 'google_scholar_author',
#   'author_id': 'CnTTa3EAAAAJ',
#   'hl': 'en'},
#  'author': {'name': 'Haozhou WANG',
#   'affiliations': 'University of Tokyo',
#   'email': 'Verified email at g.ecc.utokyo.ac.jp',
#   'website': 'http://haozhou.wang/',
#   'interests': [{'title': 'Forest Inventory',
#     'link': 'https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:forest_inventory',
# ...

# %%
results['cited_by']
# Out:
# {'table': [{'citations': {'all': 313, 'since_2020': 312}},
#   {'h_index': {'all': 8, 'since_2020': 8}},
#   {'i10_index': {'all': 7, 'since_2020': 7}}],
#  'graph': [{'year': 2019, 'citations': 1},
#   {'year': 2020, 'citations': 9},
#   {'year': 2021, 'citations': 33},
#   {'year': 2022, 'citations': 51},
#   {'year': 2023, 'citations': 67},
#   {'year': 2024, 'citations': 99},
#   {'year': 2025, 'citations': 51}]}

# %%
results['cited_by']['table']
# Out:
# [{'citations': {'all': 313, 'since_2020': 312}},
#  {'h_index': {'all': 8, 'since_2020': 8}},
#  {'i10_index': {'all': 7, 'since_2020': 7}}]

# %%
print(f"作者: {results.get('author', {}).get('name')}")
# Out:
# 作者: Haozhou WANG
